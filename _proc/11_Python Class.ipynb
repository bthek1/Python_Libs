# %% [raw]
# ---
# description: Python class (coming soon)
# output-file: python class.html
# skip_exec: true
# skip_showdoc: true
# title: Python Class
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# Special methods you should probably know about (see data model link above) are:
#
# - `__getitem__`
# - `__getattr__`
# - `__setattr__`
# - `__del__`
# - `__init__`
# - `__new__`
# - `__enter__`
# - `__exit__`
# - `__len__`
# - `__repr__`
# - `__str__`
# - `__iter__`
# - `__call__`
